# %% [markdown]
# # Time Series Data Analysis using Pandas
#
# - Created by Clayton Miller - clayton@nus.edu.sg - miller.clayton@gmail.com
#
# This notebook is an introduction to several key time-series functions available in the Pandas library.
#
# Several portions of the function explanations are from: https://www.dataquest.io/blog/tutorial-time-series-analysis-with-pandas/

# %% [markdown]
# ## The Building Data Genome Project
#
# For this set of videos, we will be using the Building Data Genome Project:
#
# https://github.com/buds-lab/the-building-data-genome-project
#
# ![alt text](https://raw.githubusercontent.com/buds-lab/the-building-data-genome-project/master/figures/buildingdatagenome1.png)
#
# This project is a set of 500+ time-series meter data from buildings -- check out the website which includes an overview of the data set, sources, and publications that use the data set.
#
# In this notebook, we will use some of the buildings from that data set to understand why Pandas was designed for time-series data from IoT networks
#
# First, we will load the libraries and mount the drives as usual

# %%
import pandas as pd
import os

# %%
# Estas duas linhas são para o ambiente Google Colab
#from google.colab import drive
#drive.mount('/content/gdrive')

# %%
#os.chdir("/content/gdrive/My Drive/EDX Data Science for Construction, Architecture and Engineering/3 - Construction - Pandas Fundamentals/meter_data/")

os.chdir("C:/Users/Renato/OneDrive/github/data_science_for_arch/Data_Science_for_Construction_Architecture_and_Engineering/3 - Construction - Pandas Fundamentals/meter_data/")

# %% [markdown]
# Let's begin this demonstration of time-series data analysis by loading the data from a single building from the `Building Data Genome Project` -- this building has the name `Abilgail`
#
# You can notice that this time there is a column in the data set called `timestamp`. If we load the DataFrame the usual way then this column will just be a string data type:

# %%
abigail = pd.read_csv('Office_Abigail.csv', index_col = "timestamp")

# %%
abigail.head()
# Out:
#                      Office_Abigail
# timestamp
# 2015-01-01 00:00:00            5.33
# 2015-01-01 01:00:00            5.41
# 2015-01-01 02:00:00            5.60
# 2015-01-01 03:00:00            6.50
# 2015-01-01 04:00:00            5.39

# %%
abigail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8760 entries, 2015-01-01 00:00:00 to 2015-12-31 23:00:00
# Data columns (total 1 columns):
# Office_Abigail    8760 non-null float64
# dtypes: float64(1)
# memory usage: 136.9+ KB

# %%
abigail.index[0]
# Out:
# '2015-01-01 00:00:00'

# %% [markdown]
# ## Setting the `timestamp` index to a *datetime* object
#
# Pandas has several very useful functions that we will cover in this notebook, but first we need to indicate to Pandas that the index is not just a regular string -- it has information related to date and time attributes including whether the day is **Monday** or **Tuesday** or whether that is a weekday or weekend.
#
# We can tell the `.read_csv()` function that it should **parse** the index and try to convert it into a *datetime* object. Let's see what happens when we do that.

# %%
abigail = pd.read_csv('Office_Abigail.csv', index_col = "timestamp", parse_dates=True)

# %%
abigail.head()
# Out:
#                      Office_Abigail
# timestamp
# 2015-01-01 00:00:00            5.33
# 2015-01-01 01:00:00            5.41
# 2015-01-01 02:00:00            5.60
# 2015-01-01 03:00:00            6.50
# 2015-01-01 04:00:00            5.39

# %%
abigail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8760 entries, 2015-01-01 00:00:00 to 2015-12-31 23:00:00
# Data columns (total 1 columns):
# Office_Abigail    8760 non-null float64
# dtypes: float64(1)
# memory usage: 136.9 KB

# %%
abigail.index[0]
# Out:
# Timestamp('2015-01-01 00:00:00')

# %% [markdown]
# ## `Timestamp` object attributes
#
# You will notice that the index is not what's known as a `DateTimeIndex` and each of the index items is a `Timestamp` object. This allows us to as the object things like what day of the week it is and other attributes.
#
# More info here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timestamp.html

# %%
abigail.index
# Out:
# DatetimeIndex(['2015-01-01 00:00:00', '2015-01-01 01:00:00',
#                '2015-01-01 02:00:00', '2015-01-01 03:00:00',
#                '2015-01-01 04:00:00', '2015-01-01 05:00:00',
#                '2015-01-01 06:00:00', '2015-01-01 07:00:00',
#                '2015-01-01 08:00:00', '2015-01-01 09:00:00',
#                ...
#                '2015-12-31 14:00:00', '2015-12-31 15:00:00',
#                '2015-12-31 16:00:00', '2015-12-31 17:00:00',
#                '2015-12-31 18:00:00', '2015-12-31 19:00:00',
#                '2015-12-31 20:00:00', '2015-12-31 21:00:00',
#                '2015-12-31 22:00:00', '2015-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='timestamp', length=8760, freq=None)

# %%
abigail.index[0].month
# Out:
# 1

# %%
abigail.index[0].dayofweek
# Out:
# 3

# %%
abigail.index[0].week
# Out:
# 1

# %%
abigail.index[0].is_leap_year
# Out:
# False

# %%
abigail.index[0].hour
# Out:
# 0

# %% [markdown]
# # Plotting simple line charts of time-series data
#
# The first thing we can do with the data is to explore it as a line chart. This gives us an understanding of the shape, frequency and potential for outliers. Data exploration is the first step in the analysis process.

# %%
abigail.plot()

# %%
abigail.plot(marker='.', alpha=0.5, linestyle='None', figsize=(15, 5))

# %% [markdown]
# # Resample the data to other frequencies
#
# "It is often useful to resample our time series data to a lower or higher frequency. Resampling to a lower frequency (downsampling) usually involves an aggregation operation — for example, computing monthly sales totals from daily data. The daily OPSD data we’re working with in this tutorial was downsampled from the original hourly time series. Resampling to a higher frequency (upsampling) is less common and often involves interpolation or other data filling method — for example, interpolating hourly weather data to 10 minute intervals for input to a scientific model.
#
# We will focus here on downsampling, exploring how it can help us analyze our OPSD data on various time scales. We use the DataFrame’s `resample()` method, which splits the DatetimeIndex into time bins and groups the data by time bin. The `resample()` method returns a Resampler object, similar to a pandas GroupBy object. We can then apply an aggregation method such as `mean()`, `median()`, `sum()`, etc., to the data group for each time bin." -- from: https://www.dataquest.io/blog/tutorial-time-series-analysis-with-pandas/

# %%
abigail.head()
# Out:
#                      Office_Abigail
# timestamp
# 2015-01-01 00:00:00            5.33
# 2015-01-01 01:00:00            5.41
# 2015-01-01 02:00:00            5.60
# 2015-01-01 03:00:00            6.50
# 2015-01-01 04:00:00            5.39

# %% [markdown]
# We can first resample to daily data by using the `D` as an attribute in the `.resample()` function to indicate that we want *daily* data aggregation. We use the `.mean()` function to indicate that we want the function to take the average across each day's hourly readings to produce the aggregated value for the day

# %%
abigail_daily = abigail.resample("D").mean()

# %%
abigail_daily.head()
# Out:
#             Office_Abigail
# timestamp
# 2015-01-01        5.533750
# 2015-01-02       10.226771
# 2015-01-03       10.439167
# 2015-01-04        9.073333
# 2015-01-05        8.677500

# %%
abigail_daily.plot(figsize=(10,5))

# %% [markdown]
# We can do the same to create *monthly* data and other aggregations

# %%
abigail_daily.resample("M").mean().plot(figsize=(10,5))

# %% [markdown]
# ## Frequencies
#
# The Pandas Library has dozens of **frequencies** that can be used to resample data -- the detailed list is here: https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects

# %% [markdown]
# # Truncating Time-Series Data
#
# The truncate function allows us to slice the data into smaller dataframes according to a time range
#
# Pandas DataFrame.truncate() function is used to truncate a Series or DataFrame before and after some index value. This is a useful shorthand for boolean indexing based on index values above or below certain thresholds.
#
# https://www.geeksforgeeks.org/python-pandas-dataframe-truncate/

# %%
abigail_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2015-01-01 to 2015-12-31
# Freq: D
# Data columns (total 1 columns):
# Office_Abigail    365 non-null float64
# dtypes: float64(1)
# memory usage: 5.7 KB

# %%
abigail_daily_june = abigail_daily.truncate(before = '2015-06-01', after='2015-07-01')

# %%
abigail_daily_june.plot(figsize=(10,5))

# %% [markdown]
# # Trends Analysis and Rolling Windows
#
# "Time series data often exhibit some slow, gradual variability in addition to higher frequency variability such as seasonality and noise. An easy way to visualize these trends is with rolling means at different time scales.
#
# A rolling mean tends to smooth a time series by averaging out variations at frequencies much higher than the window size and averaging out any seasonality on a time scale equal to the window size. This allows lower-frequency variations in the data to be explored. Since our electricity consumption time series has weekly and yearly seasonality, let’s look at rolling means on those two time scales." - https://www.dataquest.io/blog/tutorial-time-series-analysis-with-pandas/

# %%
abigail.rolling(window=500, center=True, min_periods=500).mean().plot()

# %% [markdown]
# # Analysis of a large number of buildings at once
#
# Let's look at a larger group of buildings to understand how these functions can enhanced the analysis of a large number of buildings

# %%
os.listdir()
# Out:
# ['Office_Abbey.csv',
#  'Office_Abigail.csv',
#  'Office_Abigail.xlsx',
#  'Office_Al.csv',
#  'Office_Alannah.csv',
#  'Office_Aliyah.csv',
#  'Office_Allyson.csv',
#  'Office_Alyson.csv',
#  'Office_Amelia.csv',
#  'Office_Amelie.csv',
#  'Office_Anastasia.csv',
#  'Office_Andrea.csv',
#  'Office_Angelica.csv',
#  'Office_Angelina.csv',
#  'Office_Angelo.csv',
#  'Office_Annika.csv',
#  'Office_Ashanti.csv',
#  'Office_Asher.csv',
#  'Office_Aubrey.csv',
#  'Office_Autumn.csv',
#  'Office_Ava.csv',
#  'Office_Ayden.csv',
#  'Office_Ayesha.csv',
#  'Office_Benjamin.csv',
#  'Office_Benthe.csv',
#  'Office_Bianca.csv',
#  'Office_Bobbi.csv',
#  'Office_Brian.csv',
#  'Office_Bryon.csv',
#  'Office_Caleb.csv',
#  'Office_Cameron.csv',
#  'Office_Carissa.csv',
#  'Office_Carolina.csv',
#  'Office_Catherine.csv',
#  'Office_Cecelia.csv',
#  'Office_Charles.csv',
#  'Office_Clarissa.csv',
#  'Office_Clifton.csv',
#  'Office_Clinton.csv',
#  'Office_Cody.csv',
#  'Office_Colby.csv',
#  'Office_Conrad.csv',
#  'Office_Cora.csv',
#  'Office_Corbin.csv',
#  'Office_Cristina.csv',
#  'Office_Curt.csv',
#  'Office_Dawn.csv',
#  'Office_Dorian.csv',
#  'Office_Eddie.csv',
#  'Office_Eileen.csv',
#  'Office_Elena.csv',
#  'Office_Elizabeth.csv',
#  'Office_Ellie.csv',
#  'Office_Elliot.csv',
#  'Office_Ellis.csv',
#  'Office_Emer.csv',
#  'Office_Emerald.csv',
#  'Office_Erik.csv',
#  'Office_Evelyn.csv',
#  'Office_Gabriela.csv',
#  'Office_Garman.csv',
#  'Office_Garrett.csv',
#  'Office_Gemma.csv',
#  'Office_Georgia.csv',
#  'Office_Gisselle.csv',
#  'Office_Gladys.csv',
#  'Office_Glenda.csv',
#  'Office_Glenn.csv',
#  'Office_Gloria.csv',
#  'Office_Guillermo.csv',
#  'Office_Gustavo.csv',
#  'Office_Jackie.csv',
#  'Office_Jackson.csv',
#  'Office_Jan.csv',
#  'Office_Javon.csv',
#  'Office_Jayden.csv',
#  'Office_Jeanne.csv',
#  'Office_Jerry.csv',
#  'Office_Jesus.csv',
#  'Office_Jett.csv',
#  'Office_Joan.csv',
#  'Office_John.csv',
#  'Office_Joni.csv',
#  'Office_Jude.csv',
#  'Office_Lane.csv',
#  'Office_Leland.csv',
#  'Office_Lena.csv',
#  'Office_Lesa.csv',
#  'Office_Lillian.csv',
#  'Office_Louise.csv',
#  'Office_Luann.csv',
#  'Office_Mada.csv',
#  'Office_Madeleine.csv',
#  'Office_Madisyn.csv',
#  'Office_Malik.csv',
#  'Office_Marc.csv',
#  'Office_Marcia.csv',
#  'Office_Marcus.csv',
#  'Office_Marianne.csv',
#  'Office_Marilyn.csv',
#  'Office_Marion.csv',
#  'Office_Mark.csv',
#  'Office_Marla.csv',
#  'Office_Marlon.csv',
#  'Office_Martha.csv',
#  'Office_Martin.csv',
#  'Office_Marvin.csv',
#  'Office_Mary.csv',
#  'Office_Maryann.csv',
#  'Office_Mason.csv',
#  'Office_Mat.csv',
#  'Office_Matthew.csv',
#  'Office_Max.csv',
#  'Office_Maximus.csv',
#  'Office_Maya.csv',
#  'Office_Megan.csv',
#  'Office_Melinda.csv',
#  'Office_Mercedes.csv',
#  'Office_Michael.csv',
#  'Office_Micheal.csv',
#  'Office_Mick.csv',
#  'Office_Mikayla.csv',
#  'Office_Milton.csv',
#  'Office_Mohammed.csv',
#  'Office_Moises.csv',
#  'Office_Monty.csv',
#  'Office_Morgan.csv',
#  'Office_Moses.csv',
#  'Office_Muhammad.csv',
#  'Office_Myron.csv',
#  'Office_Natasha.csv',
#  'Office_Nelson.csv',
#  'Office_Noel.csv',
#  'Office_Paige.csv',
#  'Office_Pam.csv',
#  'Office_Pamela.csv',
#  'Office_Pasquale.csv',
#  'Office_Pat.csv',
#  'Office_Patricia.csv',
#  'Office_Paula.csv',
#  'Office_Paulette.csv',
#  'Office_Paulina.csv',
#  'Office_Pauline.csv',
#  'Office_Penny.csv',
#  'Office_Perla.csv',
#  'Office_Phebian.csv',
#  'Office_Precious.csv',
#  'Office_Scottie.csv',
#  'Office_Shari.csv',
#  'Office_Shawnette.csv',
#  'Office_Shelly.csv',
#  'Office_Sinead.csv',
#  'Office_Skyler.csv',
#  'Office_Stella.csv',
#  'Office_Terrell.csv',
#  'Office_Tod.csv',
#  'Office_Travis.csv',
#  'PrimClass_Angel.csv',
#  'PrimClass_Angela.csv',
#  'PrimClass_Ebony.csv',
#  'PrimClass_Edmund.csv',
#  'PrimClass_Edwin.csv',
#  'PrimClass_Eleanor.csv',
#  'PrimClass_Eli.csv',
#  'PrimClass_Elijah.csv',
#  'PrimClass_Elisabeth.csv',
#  'PrimClass_Ellen.csv',
#  'PrimClass_Elliott.csv',
#  'PrimClass_Elmer.csv',
#  'PrimClass_Emanuela.csv',
#  'PrimClass_Emilio.csv',
#  'PrimClass_Emily.csv',
#  'PrimClass_Eoghan.csv',
#  'PrimClass_Ernest.csv',
#  'PrimClass_Ernesto.csv',
#  'PrimClass_Ervin.csv',
#  'PrimClass_Esmeralda.csv',
#  'PrimClass_Ethan.csv',
#  'PrimClass_Ethel.csv',
#  'PrimClass_Eva.csv',
#  'PrimClass_Everett.csv',
#  'PrimClass_Evie.csv',
#  'PrimClass_Ezekiel.csv',
#  'PrimClass_Ezra.csv',
#  'PrimClass_Jacob.csv',
#  'PrimClass_Jacqueline.csv',
#  'PrimClass_Jacquelyn.csv',
#  'PrimClass_Jaden.csv',
#  'PrimClass_Jaiden.csv',
#  'PrimClass_Jake.csv',
#  'PrimClass_Jamal.csv',
#  'PrimClass_Jamie.csv',
#  'PrimClass_Jane.csv',
#  'PrimClass_Janelle.csv',
#  'PrimClass_Janet.csv',
#  'PrimClass_Janice.csv',
#  'PrimClass_Janie.csv',
#  'PrimClass_Janis.csv',
#  'PrimClass_Janiya.csv',
#  'PrimClass_Jaqueline.csv',
#  'PrimClass_Jarrett.csv',
#  'PrimClass_Jasmine.csv',
#  'PrimClass_Javier.csv',
#  'PrimClass_Jaxson.csv',
#  'PrimClass_Jayda.csv',
#  'PrimClass_Jayla.csv',
#  'PrimClass_Jaylin.csv',
#  'PrimClass_Jaylinn.csv',
#  'PrimClass_Jayson.csv',
#  'PrimClass_Jazmin.csv',
#  'PrimClass_Jazmine.csv',
#  'PrimClass_Jean.csv',
#  'PrimClass_Jeanette.csv',
#  'PrimClass_Jeanine.csv',
#  'PrimClass_Jeannine.csv',
#  'PrimClass_Jediah.csv',
#  'PrimClass_Jeff.csv',
#  'PrimClass_Jeffery.csv',
#  'PrimClass_Jeffrey.csv',
#  'PrimClass_Jenna.csv',
#  'PrimClass_Jennie.csv',
#  'PrimClass_Jennifer.csv',
#  'PrimClass_Jensen.csv',
#  'PrimClass_Jeremy.csv',
#  'PrimClass_Jermaine.csv',
#  'PrimClass_Jerome.csv',
#  'PrimClass_Jesse.csv',
#  'PrimClass_Jessie.csv',
#  'PrimClass_Jill.csv',
#  'PrimClass_Jim.csv',
#  'PrimClass_Jimmie.csv',
#  'PrimClass_Joanna.csv',
#  'PrimClass_Jocelyn.csv',
#  'PrimClass_Jodie.csv',
#  'PrimClass_Jody.csv',
#  'PrimClass_Joel.csv',
#  'PrimClass_Joey.csv',
#  'PrimClass_Johanna.csv',
#  'PrimClass_Johnathan.csv',
#  'PrimClass_Johnathon.csv',
#  'PrimClass_Johnnie.csv',
#  'PrimClass_Jolie.csv',
#  'PrimClass_Jon.csv',
#  'PrimClass_Jonathon.csv',
#  'PrimClass_Jose.csv',
#  'PrimClass_Joselyn.csv',
#  'PrimClass_Josephine.csv',
#  'PrimClass_Josue.csv',
#  'PrimClass_Juanita.csv',
#  'PrimClass_Judith.csv',
#  'PrimClass_Judy.csv',
#  'PrimClass_Julian.csv',
#  'PrimClass_Julianna.csv',
#  'PrimClass_Julianne.csv',
#  'PrimClass_Julio.csv',
#  'PrimClass_Julius.csv',
#  'PrimClass_Justice.csv',
#  'PrimClass_Justin.csv',
#  'PrimClass_Ulysses.csv',
#  'PrimClass_Uma.csv',
#  'PrimClass_Umar.csv',
#  'PrimClass_Uriah.csv',
#  'UnivClass_Abby.csv',
#  'UnivClass_Abraham.csv',
#  'UnivClass_Adrienne.csv',
#  'UnivClass_Aidan.csv',
#  'UnivClass_Alec.csv',
#  'UnivClass_Alejandra.csv',
#  'UnivClass_Alexander.csv',
#  'UnivClass_Alexandra.csv',
#  'UnivClass_Alexandria.csv',
#  'UnivClass_Alexus.csv',
#  'UnivClass_Alfredo.csv',
#  'UnivClass_Alicia.csv',
#  'UnivClass_Allen.csv',
#  'UnivClass_Alvin.csv',
#  'UnivClass_Amari.csv',
#  'UnivClass_Amya.csv',
#  'UnivClass_Anamaria.csv',
#  'UnivClass_Andy.csv',
#  'UnivClass_Anika.csv',
#  'UnivClass_Annabella.csv',
#  'UnivClass_Anne.csv',
#  'UnivClass_Annmarie.csv',
#  'UnivClass_Antoinette.csv',
#  'UnivClass_Anya.csv',
#  'UnivClass_Aoibhe.csv',
#  'UnivClass_Archie.csv',
#  'UnivClass_Ariana.csv',
#  'UnivClass_Armando.csv',
#  'UnivClass_Axel.csv',
#  'UnivClass_Ayanna.csv',
#  'UnivClass_Beatrice.csv',
#  'UnivClass_Bob.csv',
#  'UnivClass_Boyd.csv',
#  'UnivClass_Brett.csv',
#  'UnivClass_Caitlyn.csv',
#  'UnivClass_Calvin.csv',
#  'UnivClass_Camden.csv',
#  'UnivClass_Candy.csv',
#  'UnivClass_Caoimhe.csv',
#  'UnivClass_Carl.csv',
#  'UnivClass_Carolyn.csv',
#  'UnivClass_Cathleen.csv',
#  'UnivClass_Celia.csv',
#  'UnivClass_Chandler.csv',
#  'UnivClass_Charlie.csv',
#  'UnivClass_Christian.csv',
#  'UnivClass_Ciara.csv',
#  'UnivClass_Clay.csv',
#  'UnivClass_Clifford.csv',
#  'UnivClass_Colette.csv',
#  'UnivClass_Conner.csv',
#  'UnivClass_Conor.csv',
#  'UnivClass_Craig.csv',
#  'UnivClass_Jadon.csv',
#  'UnivClass_Maddison.csv',
#  'UnivClass_Nash.csv',
#  'UnivClass_Nathaniel.csv',
#  'UnivClass_Nayeli.csv',
#  'UnivClass_Nelly.csv',
#  'UnivClass_Nicholas.csv',
#  'UnivClass_Nickolas.csv',
#  'UnivClass_Nishka.csv',
#  'UnivClass_Noreen.csv',
#  'UnivClass_Pandora.csv',
#  'UnivClass_Pete.csv',
#  'UnivClass_Peter.csv',
#  'UnivClass_Philip.csv',
#  'UnivClass_Phyllis.csv',
#  'UnivClass_Sam.csv',
#  'UnivClass_Seb.csv',
#  'UnivClass_Serenity.csv',
#  'UnivClass_Shawna.csv',
#  'UnivClass_Sheila.csv',
#  'UnivClass_Stephanie.csv',
#  'UnivClass_Stephen.csv',
#  'UnivClass_Stuart.csv',
#  'UnivClass_Sylvia.csv',
#  'UnivClass_Tammy.csv',
#  'UnivClass_Tamra.csv',
#  'UnivClass_Teri.csv',
#  'UnivClass_Therese.csv',
#  'UnivDorm_Adan.csv',
#  'UnivDorm_Adriana.csv',
#  'UnivDorm_Ahmad.csv',
#  'UnivDorm_Alex.csv',
#  'UnivDorm_Alka.csv',
#  'UnivDorm_Alonzo.csv',
#  'UnivDorm_Alphonso.csv',
#  'UnivDorm_Alyshialynn.csv',
#  'UnivDorm_Alyssa.csv',
#  'UnivDorm_Antonio.csv',
#  'UnivDorm_April.csv',
#  'UnivDorm_Ashleigh.csv',
#  'UnivDorm_Avery.csv',
#  'UnivDorm_Camila.csv',
#  'UnivDorm_Candace.csv',
#  'UnivDorm_Cara.csv',
#  'UnivDorm_Carey.csv',
#  'UnivDorm_Carla.csv',
#  'UnivDorm_Carter.csv',
#  'UnivDorm_Casey.csv',
#  'UnivDorm_Cathal.csv',
#  'UnivDorm_Cathalina.csv',
#  'UnivDorm_Cecilia.csv',
#  'UnivDorm_Celeste.csv',
#  'UnivDorm_Chelsey.csv',
#  'UnivDorm_Cheri.csv',
#  'UnivDorm_Chester.csv',
#  'UnivDorm_Cheyenne.csv',
#  'UnivDorm_Christi.csv',
#  'UnivDorm_Christopher.csv',
#  'UnivDorm_Cian.csv',
#  'UnivDorm_Ciaran.csv',
#  'UnivDorm_Claudia.csv',
#  'UnivDorm_Clayton.csv',
#  'UnivDorm_Colton.csv',
#  'UnivDorm_Constance.csv',
#  'UnivDorm_Cooper.csv',
#  'UnivDorm_Corey.csv',
#  'UnivDorm_Cornelius.csv',
#  'UnivDorm_Curtis.csv',
#  'UnivDorm_Jeannette.csv',
#  'UnivDorm_Laura.csv',
#  'UnivDorm_Lawrence.csv',
#  'UnivDorm_Leann.csv',
#  'UnivDorm_Leonard.csv',
#  'UnivDorm_Leslie.csv',
#  'UnivDorm_Leticia.csv',
#  'UnivDorm_Lorraine.csv',
#  'UnivDorm_Lysander.csv',
#  'UnivDorm_Malachi.csv',
#  'UnivDorm_Malcolm.csv',
#  'UnivDorm_Marlene.csv',
#  'UnivDorm_Marquis.csv',
#  'UnivDorm_Mathew.csv',
#  'UnivDorm_Mauricio.csv',
#  'UnivDorm_Mckenzie.csv',
#  'UnivDorm_Mitch.csv',
#  'UnivDorm_Paola.csv',
#  'UnivDorm_Patrice.csv',
#  'UnivDorm_Patti.csv',
#  'UnivDorm_Patty.csv',
#  'UnivDorm_Payton.csv',
#  'UnivDorm_Pedro.csv',
#  'UnivDorm_Petar.csv',
#  'UnivDorm_Phillip.csv',
#  'UnivDorm_Phoebe.csv',
#  'UnivDorm_Piper.csv',
#  'UnivDorm_Poppy.csv',
#  'UnivDorm_Prince.csv',
#  'UnivDorm_Una.csv',
#  'UnivLab_Adrian.csv',
#  'UnivLab_Aine.csv',
#  'UnivLab_Alaina.csv',
#  'UnivLab_Albert.csv',
#  'UnivLab_Alberto.csv',
#  'UnivLab_Alexis.csv',
#  'UnivLab_Alfonso.csv',
#  'UnivLab_Ali.csv',
#  'UnivLab_Alina.csv',
#  'UnivLab_Alisa.csv',
#  'UnivLab_Allan.csv',
#  'UnivLab_Allison.csv',
#  'UnivLab_Amaya.csv',
#  'UnivLab_Amy.csv',
#  'UnivLab_Ana.csv',
#  'UnivLab_Andre.csv',
#  'UnivLab_Angie.csv',
#  'UnivLab_Anita.csv',
#  'UnivLab_Aniya.csv',
#  'UnivLab_Annabelle.csv',
#  'UnivLab_Annette.csv',
#  'UnivLab_Aoife.csv',
#  'UnivLab_Arianna.csv',
#  'UnivLab_Ariel.csv',
#  'UnivLab_Ashlee.csv',
#  'UnivLab_Ashlynn.csv',
#  'UnivLab_Ashton.csv',
#  'UnivLab_Audra.csv',
#  'UnivLab_Aurora.csv',
#  'UnivLab_Bert.csv',
#  'UnivLab_Beth.csv',
#  'UnivLab_Bethany.csv',
#  'UnivLab_Brad.csv',
#  'UnivLab_Brenna.csv',
#  'UnivLab_Caesar.csv',
#  'UnivLab_Caitlin.csv',
#  'UnivLab_Callie.csv',
#  'UnivLab_Cam.csv',
#  'UnivLab_Camryn.csv',
#  'UnivLab_Carley.csv',
#  'UnivLab_Carlos.csv',
#  'UnivLab_Carlton.csv',
#  'UnivLab_Carol.csv',
#  'UnivLab_Carole.csv',
#  'UnivLab_Cayden.csv',
#  'UnivLab_Cecil.csv',
#  'UnivLab_Cedric.csv',
#  'UnivLab_Cesar.csv',
#  'UnivLab_Cheyanne.csv',
#  'UnivLab_Christine.csv',
#  'UnivLab_Christy.csv',
#  'UnivLab_Ciel.csv',
#  'UnivLab_Cindy.csv',
#  'UnivLab_Clint.csv',
#  'UnivLab_Clodagh.csv',
#  'UnivLab_Collin.csv',
#  'UnivLab_Cory.csv',
#  'UnivLab_Cristian.csv',
#  'UnivLab_Crystal.csv',
#  'UnivLab_Dianna.csv',
#  'UnivLab_Lauren.csv',
#  'UnivLab_Lea.csv',
#  'UnivLab_Lee.csv',
#  'UnivLab_Lester.csv',
#  'UnivLab_Levi.csv',
#  'UnivLab_Lilly.csv',
#  'UnivLab_Louie.csv',
#  'UnivLab_Lyle.csv',
#  'UnivLab_Mack.csv',
#  'UnivLab_Madelyn.csv',
#  'UnivLab_Margret.csv',
#  'UnivLab_Mariana.csv',
#  'UnivLab_Marie.csv',
#  'UnivLab_Mario.csv',
#  'UnivLab_Marshall.csv',
#  'UnivLab_Miles.csv',
#  'UnivLab_Neil.csv',
#  'UnivLab_Paris.csv',
#  'UnivLab_Parker.csv',
#  'UnivLab_Patrick.csv',
#  'UnivLab_Patsy.csv',
#  'UnivLab_Paul.csv',
#  'UnivLab_Peggy.csv',
#  'UnivLab_Peyton.csv',
#  'UnivLab_Phil.csv',
#  'UnivLab_Preston.csv',
#  'UnivLab_Priscilla.csv',
#  'UnivLab_Santiago.csv',
#  'UnivLab_Susan.csv',
#  'UnivLab_Suzette.csv',
#  'UnivLab_Tami.csv',
#  'UnivLab_Taylor.csv',
#  'UnivLab_Terrie.csv',
#  'UnivLab_Tracie.csv',
#  'UnivLab_Tracy.csv']

# %% [markdown]
# Using that list, let's take all the buildings that have a time range of 2015

# %%
list_of_buildings = ['UnivClass_Andy.csv',
'Office_Abbey.csv',
'Office_Alannah.csv',
'PrimClass_Angel.csv',
'Office_Penny.csv',
'Office_Pam.csv',
'UnivClass_Craig.csv',
'UnivLab_Allison.csv',
'Office_Amelia.csv',
'Office_Aubrey.csv',
'Office_Cecelia.csv',
'UnivClass_Conor.csv',
'Office_Autumn.csv',
'Office_Abigail.csv',
'Office_Amelie.csv',
'UnivClass_Alfredo.csv',
'Office_Phebian.csv',
'UnivLab_Adrian.csv',
'UnivDorm_Curtis.csv',
'UnivLab_Angie.csv',
'UnivClass_Amya.csv',
'UnivDorm_Cian.csv',
'UnivClass_Ciara.csv',
'UnivLab_Audra.csv',
'UnivLab_Ciel.csv',
'UnivLab_Cesar.csv']

# %%
all_data_list = []
for buildingname in list_of_buildings:
  df = pd.read_csv(buildingname, index_col = "timestamp", parse_dates=True) 
  df = df.resample("H").mean()
  all_data_list.append(df)
all_data = pd.concat(all_data_list, axis=1)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8760 entries, 2015-01-01 00:00:00 to 2015-12-31 23:00:00
# Freq: H
# Data columns (total 26 columns):
# UnivClass_Andy       8760 non-null float64
# Office_Abbey         8760 non-null float64
# Office_Alannah       8760 non-null float64
# PrimClass_Angel      8760 non-null float64
# Office_Penny         8759 non-null float64
# Office_Pam           8759 non-null float64
# UnivClass_Craig      8759 non-null float64
# UnivLab_Allison      8760 non-null float64
# Office_Amelia        8760 non-null float64
# Office_Aubrey        8760 non-null float64
# Office_Cecelia       8759 non-null float64
# UnivClass_Conor      8759 non-null float64
# Office_Autumn        8760 non-null float64
# Office_Abigail       8760 non-null float64
# Office_Amelie        8760 non-null float64
# UnivClass_Alfredo    8760 non-null float64
# Office_Phebian       8759 non-null float64
# UnivLab_Adrian       8760 non-null float64
# UnivDorm_Curtis      8759 non-null float64
# UnivLab_Angie        8760 non-null float64
# UnivClass_Amya       8760 non-null float64
# UnivDorm_Cian        8759 non-null float64
# UnivClass_Ciara      8759 non-null float64
# UnivLab_Audra        8760 non-null float64
# UnivLab_Ciel         8759 non-null float64
# UnivLab_Cesar        8759 non-null float64
# dtypes: float64(26)
# memory usage: 2.1 MB

# %%
all_data.plot(figsize=(20,30), subplots=True);

# %%
all_data.resample("D").mean().plot(figsize=(20,30), subplots=True);

# %%
all_data.resample("D").mean().truncate(after='2015-06-01').plot(figsize=(20,30), subplots=True);

# %% [markdown]
# ## Filter columns by query
#
# Let's just look at the *office* buildings by filtering the columns based on name

# %%
all_data.columns[all_data.columns.str.contains("Office")]
# Out:
# Index(['Office_Abbey', 'Office_Alannah', 'Office_Penny', 'Office_Pam',
#        'Office_Amelia', 'Office_Aubrey', 'Office_Cecelia', 'Office_Autumn',
#        'Office_Abigail', 'Office_Amelie', 'Office_Phebian'],
#       dtype='object')

# %%
all_data[all_data.columns[all_data.columns.str.contains("Office")]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8760 entries, 2015-01-01 00:00:00 to 2015-12-31 23:00:00
# Freq: H
# Data columns (total 11 columns):
# Office_Abbey      8760 non-null float64
# Office_Alannah    8760 non-null float64
# Office_Penny      8759 non-null float64
# Office_Pam        8759 non-null float64
# Office_Amelia     8760 non-null float64
# Office_Aubrey     8760 non-null float64
# Office_Cecelia    8759 non-null float64
# Office_Autumn     8760 non-null float64
# Office_Abigail    8760 non-null float64
# Office_Amelie     8760 non-null float64
# Office_Phebian    8759 non-null float64
# dtypes: float64(11)
# memory usage: 1.1 MB

# %%
all_data[all_data.columns[all_data.columns.str.contains("Office")]].plot(figsize=(15,15), subplots=True);
